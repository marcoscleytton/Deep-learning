# %%
from keras.models import load_model  # TensorFlow
from PIL import Image, ImageOps  # PIL
import numpy as np

# Desativar a notação científica para maior clareza
np.set_printoptions(suppress=True)

# Carregar os rótulos
model = load_model("keras_Model.h5", compile=False)

# Carregar os rótulos
class_names = open("labels.txt", "r").readlines()

# Crie o array com o formato correto para alimentar o modelo do Keras
# O 'comprimento' ou número de imagens que você pode colocar no array
# é determinado pela primeira posição na tupla de formato, neste caso 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Substitua isto pelo caminho para sua imagem
image = Image.open("<IMAGE_PATH>").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# transformar a imagem em um array numpy
image_array = np.asarray(image)

# Normalizar a imagem
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Carregar a imagem no array
data[0] = normalized_image_array

# Faz a previsão com o modelo
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)

# %% [markdown]
# Se estiver trabalhando com aprendizado de máquina, esses "rótulos" geralmente representam as categorias ou classes que o modelo deve prever. Posso te ajudar a entender como eles são usados, se quiser.
#
# class_names = open().readlines()

# %% [markdown]
# Esse passo é comum em projetos de visão computacional, onde a imagem precisa ser convertida para um formato numérico que possa ser processado por bibliotecas como Keras ou TensorFlow.
# # transformar a imagem em um array numpy

# %% [markdown]
# # Normalizar a imagem
#
#
# Normalizar uma imagem geralmente significa ajustar os valores dos pixels para uma faixa específica — como de 0 a 1 — para facilitar o processamento por modelos de aprendizado de máquina.

# %% [markdown]
# # Carregar a imagem no array
#
#
# Esse passo geralmente envolve converter a imagem em uma estrutura de dados que bibliotecas como NumPy ou TensorFlow possam manipular.

# %% [markdown]
# # Faz a previsão com o modelo
# Esse comentário geralmente aparece logo antes de uma linha como:
# predictions = model.predict(image_array)
